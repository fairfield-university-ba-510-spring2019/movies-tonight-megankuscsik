# %% [markdown]
# # Movies Tonight Part 4: A few SELECT queries
# __Use `%%sql` magic to write the queries listed below.__

# %%
# load %sql magic extension
# %reload_ext sql

# initialize a database connection; may have to adjust username and password 
# %sql sqlite:///Movies.db
# Out:
# 'Connected: @Movies.db'

# %% [markdown]
# **1. Write a select query that returns the MovieTitle, TheaterName, and Showtime for each movie showing.**
# The query should use `JOIN` syntax as described in your textbook. Also, use aliases ( `… AS …` ) to make sure that column names match exactly what is asked for.

# %%
# %%sql
# SELECT Mtitle AS MovieTitle, TName AS TheaterName, ShowTime AS ShowTime
# FROM Dataset
# LIMIT 10;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM')]

# %%
**2. Write a select query to display the MovieTitle, TheaterName, and Showtime for each show after 7pm.** You can start with a copy of the previous query and then add a `WHERE` clause.

# %%
# %%sql
# SELECT Mtitle AS MovieTitle, TName AS TheaterName, ShowTime AS ShowTime
# FROM Dataset
# WHERE ShowTime > 7
# LIMIT 10;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '9:40 PM')]

# %% [markdown]
# **3. Write a select query to display the cast (actors only) of each movie.** The query should return the Movie Title, Actor Name, MID, and AID.

# %%
# %%sql
# SELECT Mtitle AS MovieTitle, CName
# FROM Dataset
# LIMIT 10;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', 'Austin Pendleton'),
#  ('Associate, The', 'Bebe Neuwirth'),
#  ('Associate, The', 'Dianne Wiest'),
#  ('Associate, The', 'Eli Wallach'),
#  ('Associate, The', 'Kenny Kerr'),
#  ('Associate, The', 'Lainie Kazan'),
#  ('Associate, The', 'Tim Daly'),
#  ('Associate, The', 'Whoopi Goldberg'),
#  ('Associate, The', 'Donald Petrie'),
#  ('Associate, The', 'Austin Pendleton')]

# %% [markdown]
# **4. Write a select query to display the number of distinct movies that each actor appears in.** The query should return the ActorName, MovieCount, and AID. You will need to use use a GROUP BY clause and the COUNT() function.

# %%
# %%sql
# SELECT COUNT (DISTINCT MTitle), CName
# FROM Dataset
# GROUP BY MTitle, CName
# LIMIT 10;
# Out:
#  * sqlite:///Movies.db
# Done.
# [(1, 'Austin Pendleton'),
#  (1, 'Bebe Neuwirth'),
#  (1, 'Dianne Wiest'),
#  (1, 'Donald Petrie'),
#  (1, 'Eli Wallach'),
#  (1, 'Kenny Kerr'),
#  (1, 'Lainie Kazan'),
#  (1, 'Tim Daly'),
#  (1, 'Whoopi Goldberg'),
#  (1, 'Campbell Scott')]

# %% [markdown]
# **5. Write a select query to display only the actors that appear in multiple movies.** The query should return the Actor Name, Movie Count, and AID. You can use the previous select query as a starting point. You will need to add a HAVING clause to do the restriction.

# %%
# %%sql
# SELECT COUNT (MTitle), CName
# FROM Dataset
# GROUP BY MTitle, CName
# HAVING MTitle > 1
# LIMIT 10;
# Out:
#  * sqlite:///Movies.db
# Done.
# [(14, 'Austin Pendleton'),
#  (14, 'Bebe Neuwirth'),
#  (14, 'Dianne Wiest'),
#  (14, 'Donald Petrie'),
#  (14, 'Eli Wallach'),
#  (14, 'Kenny Kerr'),
#  (14, 'Lainie Kazan'),
#  (14, 'Tim Daly'),
#  (14, 'Whoopi Goldberg'),
#  (12, 'Campbell Scott')]

# %% [markdown]
# **6. Write a select query to display directors that also act in their movies.** The query should return the ArtistName, NumDirectorCredits, NumActorCredits, NumDirectorActorCredits. Each count should be calculated separately using a subquery. Note: NumDirectorActorCredits should be greater than 0.

# %%
# %%sql
#     SELECT CName AS ArtistName, CCode
#     FROM Dataset
#     ;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bill Pullman', 'A'),
#  ('Bill Smitrovich', 'A'),
#  ('Harvey Fierstein', 'A'),
#  ('Jeff Goldblum', 'A'),
#  ('Judd Hirsch', 'A'),
#  ('Margaret Colin', 'A'),
#  ('Mary McDonnell', 'A'),
#  ('Randy Quaid', 'A'),
#  ('Robert Loggia', 'A'),
#  ('Vivica Fox', 'A'),
#  ('Will Smith', 'A'),
#  ('Roland Emmerich', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Emilio Estevez', 'A'),
#  ('Heidi Kling', 'A'),
#  ('Jeffrey Nordling', 'A'),
#  ('Joss Ackland', 'A'),
#  ('Rob Lieberman', 'A'),
#  ('Rob Lieberman', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('Bill Murray', 'A'),
#  ('Janeane Garofalo', 'A'),
#  ('Jeremy Piven', 'A'),
#  ('Keith David', 'A'),
#  ('Matthew McConaughey', 'A'),
#  ('Pat Hingle', 'A'),
#  ('Howard Franklin', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Joe Mantegna', 'A'),
#  ('Kari Wuhrer', 'A'),
#  ('Lucinda Jenney', 'A'),
#  ('Michael Constantine', 'A'),
#  ('Robert John Burke', 'A'),
#  ('Tom Holland', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Aidan Quinn', 'A'),
#  ('Alan Rickman', 'A'),
#  ('Julia Roberts', 'A'),
#  ('Liam Neeson', 'A'),
#  ('Stephen Rea', 'A'),
#  ('Neil Jordan', 'D'),
#  ('Aidan Quinn', 'A'),
#  ('Alan Rickman', 'A'),
#  ('Julia Roberts', 'A'),
#  ('Liam Neeson', 'A'),
#  ('Stephen Rea', 'A'),
#  ('Neil Jordan', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Campbell Scott', 'A'),
#  ('Ian Holm', 'A'),
#  ('Isabella Rossellini', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Stanley Tucci', 'A'),
#  ('Tony Shalhoub', 'A'),
#  ('Campbell Scott', 'D'),
#  ('Stanley Tucci', 'D'),
#  ('Campbell Scott', 'A'),
#  ('Ian Holm', 'A'),
#  ('Isabella Rossellini', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Stanley Tucci', 'A'),
#  ('Tony Shalhoub', 'A'),
#  ('Campbell Scott', 'D'),
#  ('Stanley Tucci', 'D'),
#  ('Campbell Scott', 'A'),
#  ('Ian Holm', 'A'),
#  ('Isabella Rossellini', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Stanley Tucci', 'A'),
#  ('Tony Shalhoub', 'A'),
#  ('Campbell Scott', 'D'),
#  ('Stanley Tucci', 'D'),
#  ('Anna Paquin', 'A'),
#  ('Dana Delany', 'A'),
#  ('Jeff Daniels', 'A'),
#  ('Carroll Ballard', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bill Pullman', 'A'),
#  ('Bill Smitrovich', 'A'),
#  ('Harvey Fierstein', 'A'),
#  ('Jeff Goldblum', 'A'),
#  ('Judd Hirsch', 'A'),
#  ('Margaret Colin', 'A'),
#  ('Mary McDonnell', 'A'),
#  ('Randy Quaid', 'A'),
#  ('Robert Loggia', 'A'),
#  ('Vivica Fox', 'A'),
#  ('Will Smith', 'A'),
#  ('Roland Emmerich', 'D'),
#  ('Bill Pullman', 'A'),
#  ('Bill Smitrovich', 'A'),
#  ('Harvey Fierstein', 'A'),
#  ('Jeff Goldblum', 'A'),
#  ('Judd Hirsch', 'A'),
#  ('Margaret Colin', 'A'),
#  ('Mary McDonnell', 'A'),
#  ('Randy Quaid', 'A'),
#  ('Robert Loggia', 'A'),
#  ('Vivica Fox', 'A'),
#  ('Will Smith', 'A'),
#  ('Roland Emmerich', 'D'),
#  ('Aidan Quinn', 'A'),
#  ('Alan Rickman', 'A'),
#  ('Julia Roberts', 'A'),
#  ('Liam Neeson', 'A'),
#  ('Stephen Rea', 'A'),
#  ('Neil Jordan', 'D'),
#  ('Aidan Quinn', 'A'),
#  ('Alan Rickman', 'A'),
#  ('Julia Roberts', 'A'),
#  ('Liam Neeson', 'A'),
#  ('Stephen Rea', 'A'),
#  ('Neil Jordan', 'D'),
#  ('Dave Chappelle', 'A'),
#  ('Eddie Murphy', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('James Coburn', 'A'),
#  ('John Ales', 'A'),
#  ('Larry Miller', 'A'),
#  ('Tom Shadyac', 'D'),
#  ('Dave Chappelle', 'A'),
#  ('Eddie Murphy', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('James Coburn', 'A'),
#  ('John Ales', 'A'),
#  ('Larry Miller', 'A'),
#  ('Tom Shadyac', 'D'),
#  ('Forest Whitaker', 'A'),
#  ('John Travolta', 'A'),
#  ('Kyra Sedgwick', 'A'),
#  ('Robert Duvall', 'A'),
#  ('Jon Turteltaub', 'D'),
#  ('Forest Whitaker', 'A'),
#  ('John Travolta', 'A'),
#  ('Kyra Sedgwick', 'A'),
#  ('Robert Duvall', 'A'),
#  ('Jon Turteltaub', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Anthony Hopkins', 'A'),
#  ('Diane Venora', 'A'),
#  ('Joan Plowright', 'A'),
#  ('Julianne Moore', 'A'),
#  ('Natascha McElhone', 'A'),
#  ('James Ivory', 'D'),
#  ('Anthony Hopkins', 'A'),
#  ('Diane Venora', 'A'),
#  ('Joan Plowright', 'A'),
#  ('Julianne Moore', 'A'),
#  ('Natascha McElhone', 'A'),
#  ('James Ivory', 'D'),
#  ('Christine Taylor', 'A'),
#  ('Christopher Daniel Barnes', 'A'),
#  ('Gary Cole', 'A'),
#  ('Henriette Mantel', 'A'),
#  ('Jennifer Elise Cox', 'A'),
#  ('Jesse Lee', 'A'),
#  ('Olivia Hack', 'A'),
#  ('Paul Sutera', 'A'),
#  ('Shelley Long', 'A'),
#  ('Tim Matheson', 'A'),
#  ('Arlene Sanford', 'D'),
#  ('Emilio Estevez', 'A'),
#  ('Heidi Kling', 'A'),
#  ('Jeffrey Nordling', 'A'),
#  ('Joss AcklandDirected by</B> Rob Lieberma', 'A'),
#  ('Rob Lieberman', 'A'),
#  ('Rob Lieberman', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Anna Paquin', 'A'),
#  ('Dana Delany', 'A'),
#  ('Jeff Daniels', 'A'),
#  ('Carroll Ballard', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('Ethan Embry', 'A'),
#  ('Johnathon Schaech', 'A'),
#  ('Steve Zahn', 'A'),
#  ('Tom Everett Scott', 'A'),
#  ('Tom Hanks', 'D'),
#  ('Ethan Embry', 'A'),
#  ('Johnathon Schaech', 'A'),
#  ('Steve Zahn', 'A'),
#  ('Tom Everett Scott', 'A'),
#  ('Tom Hanks', 'D'),
#  ('Ethan Embry', 'A'),
#  ('Johnathon Schaech', 'A'),
#  ('Steve Zahn', 'A'),
#  ('Tom Everett Scott', 'A'),
#  ('Tom Hanks', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Delroy Lindo', 'A'),
#  ('Gary Sinese', 'A'),
#  ('Lili Taylor', 'A'),
#  ('Mel Gibson', 'A'),
#  ('Rene Russo', 'A'),
#  ('Ron Howard', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('Bette Midler', 'A'),
#  ('Diane Keaton', 'A'),
#  ('Goldie Hawn', 'A'),
#  ('Hugh Wilson', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('and Louise Fletcher', 'A'),
#  ('Jon Lovitz', 'A'),
#  ('Mekhi Phifer', 'A'),
#  ('Tia Carrera', 'A'),
#  ('Hart Bochner', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Claire Danes', 'A'),
#  ('Diane Venora', 'A'),
#  ('John Leguizamo', 'A'),
#  ('Leonardo DiCaprio', 'A'),
#  ('Paul Rudd', 'A'),
#  ('Paul Sorvino', 'A'),
#  ('Baz Luhrmann', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Greg Kinnear', 'A'),
#  ('Hector Elizondo', 'A'),
#  ('Jon Seda', 'A'),
#  ('Laurie Metcalf', 'A'),
#  ('Maria Pitillo', 'A'),
#  ('Roscoe Lee Browne', 'A'),
#  ('Tim Conway', 'A'),
#  ('Garry Marshall', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bill Murray', 'A'),
#  ('Janeane Garofalo', 'A'),
#  ('Jeremy Piven', 'A'),
#  ('Keith David', 'A'),
#  ('Matthew McConaughey', 'A'),
#  ('Pat Hingle', 'A'),
#  ('Howard Franklin', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Barbra Streisand', 'A'),
#  ('Jeff Bridges', 'A'),
#  ('Lauren Bacall', 'A'),
#  ('Pierce Brosnan', 'A'),
#  ('Barbra Streisand', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Blair Underwood', 'A'),
#  ('Jada Pinkett', 'A'),
#  ('John C. McGinley', 'A'),
#  ('Kimberly Elise', 'A'),
#  ('Queen Latifah', 'A'),
#  ('Vivica Fox', 'A'),
#  ('F. Gary Gray', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('Billy Crudup', 'A'),
#  ('Brad Pitt', 'A'),
#  ('Brad Renfro', 'A'),
#  ('Dustin Hoffman', 'A'),
#  ('Jason Patric', 'A'),
#  ('Joseph Perrino', 'A'),
#  ('Kevin Bacon', 'A'),
#  ('Minnie Driver', 'A'),
#  ('Robert De Niro', 'A'),
#  ('Ron Eldard', 'A'),
#  ('Terry Kinney', 'A'),
#  ('Vittorio Gassman', 'A'),
#  ('Barry Levinson', 'D'),
#  ('CName', 'CCode'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bernard Hill', 'A'),
#  ('Brian McCardie', 'A'),
#  ('Emily Mortimer', 'A'),
#  ('Henry Cele', 'A'),
#  ('John Kani', 'A'),
#  ('Michael Douglas', 'A'),
#  ('Tom Wilkinson', 'A'),
#  ('Val Kilmer', 'A'),
#  ('Stephen Hopkins', 'D'),
#  ('Bill Pullman', 'A'),
#  ('Bill Smitrovich', 'A'),
#  ('Harvey Fierstein', 'A'),
#  ('Jeff Goldblum', 'A'),
#  ('Judd Hirsch', 'A'),
#  ('Margaret Colin', 'A'),
#  ('Mary McDonnell', 'A'),
#  ('Randy Quaid', 'A'),
#  ('Robert Loggia', 'A'),
#  ('Vivica Fox', 'A'),
#  ('Will Smith', 'A'),
#  ('Roland Emmerich', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Austin Pendleton', 'A'),
#  ('Bebe Neuwirth', 'A'),
#  ('Dianne Wiest', 'A'),
#  ('Eli Wallach', 'A'),
#  ('Kenny Kerr', 'A'),
#  ('Lainie Kazan', 'A'),
#  ('Tim Daly', 'A'),
#  ('Whoopi Goldberg', 'A'),
#  ('Donald Petrie', 'D'),
#  ('Emilio Estevez', 'A'),
#  ('Heidi Kling', 'A'),
#  ...]
